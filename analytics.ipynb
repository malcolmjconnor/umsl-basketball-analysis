# %%
import pandas
import requests
from bs4 import BeautifulSoup

# %%
url = "https://umsltritons.com/sports/mens-basketball/stats/2023-24"
response = requests.get(url)

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the section with id 'team'
    team_section = soup.find('section', id='team')

    # Check if the section is found
    if team_section:
        # Find the table containing basketball stats within the 'team' section
        team_stats_table = team_section.find('table')

        # Check if the table is found
        if team_stats_table:
            # Extract the statistics based on the HTML structure of the table
            team_stats = team_stats_table.find_all('tr')

            # Create a list to hold the rows of data
            data = []

            # Loop through each row in the table
            for stat in team_stats:
                # Extract data from each column (td) in the row
                row_data = [td.text.strip() for td in stat.find_all('td')]
                
                # Append the row data to the list
                data.append(row_data)

            # Create a Pandas DataFrame from the list of data
            df = pd.DataFrame(data)

            # Print the DataFrame
            print(df)
        else:
            print("Table not found within the 'team' section.")
    else:
        print("Section with id 'team' not found. Check the id attribute.")

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
#                                    0        1        2
# 0                               None     None     None
# 1                            Scoring     None     None
# 2                  Total Points\nTOT     1138     1231
# 3               Points Per Game\nPPG     66.9     72.4
# 4             Scoring Margin\nMargin     -5.5       --
# 5                           Shooting     None     None
# 6        FG: Made-Attempted\nFGM-FGA  425-918  435-936
# 7                FG: Percentage\nFG%     .463     .465
# 8                FG: Per Game\nFGM/G     25.0     25.6
# 9       3PT: Made-Attempted\n3PT-3PA  120-340  166-403
# 10             3PT: Percentage\n3PT%     .353     .412
# 11              3PT: Per Game\n3PT/G      7.1      9.8
# 12       FT: Made-Attempted\nFTM-FTA  168-241  195-246
# 13               FT: Percentage\nFT%     .697     .793
# 14                FT: Per Game\nFT/G      9.9     11.5
# 15                        Rebounding     None     None
# 16                        Total\nTOT      537      518
# 17                     Per Game\nRPG     31.6     30.5
# 18                            Margin      1.1       --
# 19                           Assists     None     None
# 20                        Total\nTOT      207      232
# 21                     Per Game\nAPG     12.2     13.6
# 22                         Turnovers     None     None
# 23                        Total\nTOT      210      185
# 24                    Per Game\nTO/G     12.4     10.9
# 25                            Margin     -1.5       --
# 26       Assist/Turnover Ratio\nA/TO      1.0      1.3
# 27  Points Off Turnovers\nPTS OFF TO     11.7     15.4
# 28                            Steals     None     None
# 29                        Total\nTOT       99      102
# 30                   Per Game\nSTL/G      5.8      6.0
# 31                            Blocks     None     None
# 32                        Total\nTOT       53       55
# 33                   Per Game\nBLK/G      3.1      3.2
# 34                        Attendance     None     None
# 35                        Total\nTOT      853     3061
# 36                     Per Game\nAVG    4-213    7-437

# %%
df
# Out:
#                                    0        1        2
# 0                               None     None     None
# 1                            Scoring     None     None
# 2                  Total Points\nTOT     1138     1231
# 3               Points Per Game\nPPG     66.9     72.4
# 4             Scoring Margin\nMargin     -5.5       --
# 5                           Shooting     None     None
# 6        FG: Made-Attempted\nFGM-FGA  425-918  435-936
# 7                FG: Percentage\nFG%     .463     .465
# 8                FG: Per Game\nFGM/G     25.0     25.6
# 9       3PT: Made-Attempted\n3PT-3PA  120-340  166-403
# 10             3PT: Percentage\n3PT%     .353     .412
# 11              3PT: Per Game\n3PT/G      7.1      9.8
# 12       FT: Made-Attempted\nFTM-FTA  168-241  195-246
# 13               FT: Percentage\nFT%     .697     .793
# 14                FT: Per Game\nFT/G      9.9     11.5
# 15                        Rebounding     None     None
# 16                        Total\nTOT      537      518
# 17                     Per Game\nRPG     31.6     30.5
# 18                            Margin      1.1       --
# 19                           Assists     None     None
# 20                        Total\nTOT      207      232
# 21                     Per Game\nAPG     12.2     13.6
# 22                         Turnovers     None     None
# 23                        Total\nTOT      210      185
# 24                    Per Game\nTO/G     12.4     10.9
# 25                            Margin     -1.5       --
# 26       Assist/Turnover Ratio\nA/TO      1.0      1.3
# 27  Points Off Turnovers\nPTS OFF TO     11.7     15.4
# 28                            Steals     None     None
# 29                        Total\nTOT       99      102
# 30                   Per Game\nSTL/G      5.8      6.0
# 31                            Blocks     None     None
# 32                        Total\nTOT       53       55
# 33                   Per Game\nBLK/G      3.1      3.2
# 34                        Attendance     None     None
# 35                        Total\nTOT      853     3061
# 36                     Per Game\nAVG    4-213    7-437
